# %%
library(car)

# %%
times <- read.csv("/home/ashish/HCI_LABstudies_Results/time_task1.csv", sep = ",", colClasses = c("factor", "numeric", "numeric"))
head(times)

boxplot(times$time_task1_linkedin, times$time_task1_handshake, names=c("LinkedIn", "Handshake"), main="Time Spent for applying jobs with LinkedIn vs Handshake", ylab="Time (minutes)")
# Out:
#   pid time_task1_linkedin time_task1_handshake
# 1 1   10.00               10.00
# 2 4    4.07               10.00
# 3 5    4.00                7.39
# 4 2   10.00                7.42
# 5 3    8.10               10.00
# 6 6   10.00               10.00
# Plot with title “Time Spent for applying jobs with LinkedIn vs Handshake”

# %%
clicks <- read.csv("/home/ashish/HCI_LABstudies_Results/clicks_task1.csv", sep = ",", colClasses = c("factor", "numeric", "numeric"))
head(clicks)

boxplot(clicks$clicks_task1_linkedin, clicks$clicks_task1_handshake, names=c("LinkedIn", "Handshake"), main="Number of clicks for applying jobs with LinkedIn vs Handshake", ylab="Number of clicks")
# Out:
#   pid clicks_task1_linkedin clicks_task1_handshake
# 1 1    94                   106
# 2 4    84                   158
# 3 5    66                   111
# 4 2    85                    56
# 5 3   125                    65
# 6 6    88                   100
# Plot with title “Number of clicks for applying jobs with LinkedIn vs Handshake”

# %%
times_2 <- read.csv("/home/ashish/HCI_LABstudies_Results/time_task2.csv", sep = ",", colClasses = c("factor", "numeric", "numeric"))
head(times_2)

boxplot(times_2$time_task2_linkedin, times_2$time_task2_handshake, names=c("LinkedIn", "Handshake"), main="Time Spent registering for events with LinkedIn vs Handshake", ylab="Time (minutes)")
# Out:
#   pid time_task2_linkedin time_task2_handshake
# 1 1   10.00               2.48
# 2 4    5.15               3.10
# 3 5   10.00               4.05
# 4 2    4.34               2.16
# 5 3    8.22               2.35
# 6 6    4.09               6.13
# Plot with title “Time Spent registering for events with LinkedIn vs Handshake”

# %%
clicks_2 <- read.csv("/home/ashish/HCI_LABstudies_Results/clicks_task2.csv", sep = ",", colClasses = c("factor", "numeric", "numeric"))
head(clicks)

boxplot(clicks_2$clicks_task2_linkedin, clicks_2$clicks_task2_handshake, names=c("LinkedIn", "Handshake"), main="Number of clicks for registering events with LinkedIn vs Handshake", ylab="Number of clicks")
# Out:
#   pid clicks_task1_linkedin clicks_task1_handshake
# 1 1    94                   106
# 2 4    84                   158
# 3 5    66                   111
# 4 2    85                    56
# 5 3   125                    65
# 6 6    88                   100
# Plot with title “Number of clicks for registering events with LinkedIn vs Handshake”

# %%
sus <- read.csv("/home/ashish/HCI_LABstudies_Results/sus_task1.csv", sep = ",", colClasses = c("factor", "numeric", "numeric"))
head(sus)

boxplot(sus$linkedin_task1_sus, sus$handshake_task1_sus, names=c("LinkedIn", "Handshake"), main="SUS score for applying jobs with LinkedIn vs Handshake", ylab="SUS score")
# Out:
#   pid linkedin_task1_sus handshake_task1_sus
# 1 1   80.0               82.5
# 2 4   70.0               77.5
# 3 5   87.5               87.5
# 4 2   50.0               17.5
# 5 3   60.0               70.0
# 6 6   92.5               65.0
# Plot with title “SUS score for applying jobs with LinkedIn vs Handshake”

# %%
sus_2 <- read.csv("/home/ashish/HCI_LABstudies_Results/sus_task2.csv", sep = ",", colClasses = c("factor", "numeric", "numeric"))
head(sus_2)

boxplot(sus_2$linkedin_task2_sus, sus_2$handshake_task2_sus, names=c("LinkedIn", "Handshake"), main="SUS score for registering events with LinkedIn vs Handshake", ylab="SUS score")
# Out:
#   PID linkedin_task2_sus handshake_task2_sus
# 1 1   45.0               90.0
# 2 4   27.5               85.0
# 3 5   20.0               80.0
# 4 2   95.0               45.0
# 5 3   35.0               57.5
# 6 6   65.0               75.0
# Plot with title “SUS score for registering events with LinkedIn vs Handshake”

# %%
ues_fa <- read.csv("/home/ashish/HCI_LABstudies_Results/ues_fa_task1.csv", sep = ",", colClasses = c("factor", "numeric", "numeric"))
head(ues_fa)

boxplot(ues_fa$FA_L, ues_fa$FA_H, names=c("LinkedIn", "Handshake"), main="UES FA score for applying jobs with LinkedIn vs Handshake", ylab="UES FA score")
# Out:
#   PID FA_L     FA_H
# 1 1   3.333333 3.000000
# 2 4   3.333333 4.000000
# 3 5   1.333333 3.000000
# 4 2   3.000000 3.666667
# 5 3   3.666667 3.000000
# 6 6   4.000000 3.000000
# Plot with title “UES FA score for applying jobs with LinkedIn vs Handshake”

# %%
ues_pu <- read.csv("/home/ashish/HCI_LABstudies_Results/ues_pu_task1.csv", sep = ",", colClasses = c("factor", "numeric", "numeric"))
head(ues_pu)

boxplot(ues_pu$PU_L, ues_pu$PU_H, names=c("LinkedIn", "Handshake"), main="UES PU score for applying jobs with LinkedIn vs Handshake", ylab="UES PU score")
# Out:
#   PID PU_L     PU_H
# 1 1   3.333333 4.000000
# 2 4   4.333333 5.000000
# 3 5   5.000000 3.000000
# 4 2   3.000000 1.000000
# 5 3   2.000000 4.000000
# 6 6   4.000000 4.333333
# Plot with title “UES PU score for applying jobs with LinkedIn vs Handshake”

# %%
ues_ae <- read.csv("/home/ashish/HCI_LABstudies_Results/ues_ae_task1.csv", sep = ",", colClasses = c("factor", "numeric", "numeric"))
head(ues_ae)

boxplot(ues_ae$AE_L, ues_ae$AE_H, names=c("LinkedIn", "Handshake"), main="UES AE score for applying jobs with LinkedIn vs Handshake", ylab="UES AE score")
# Out:
#   PID AE_L     AE_H
# 1 1   4.000000 3
# 2 4   3.666667 5
# 3 5   4.000000 5
# 4 2   3.666667 1
# 5 3   5.000000 2
# 6 6   3.333333 3
# Plot with title “UES AE score for applying jobs with LinkedIn vs Handshake”

# %%
ues_rw <- read.csv("/home/ashish/HCI_LABstudies_Results/ues_rw_task1.csv", sep = ",", colClasses = c("factor", "numeric", "numeric"))
head(ues_rw)

boxplot(ues_rw$RW_L, ues_rw$RW_H, names=c("LinkedIn", "Handshake"), main="UES RW score for applying jobs with LinkedIn vs Handshake", ylab="UES RW score")
# Out:
#   PID RW_L     RW_H
# 1 1   2.666667 3.333333
# 2 4   3.333333 4.000000
# 3 5   5.000000 5.000000
# 4 2   3.666667 1.000000
# 5 3   2.333333 5.000000
# 6 6   3.666667 2.000000
# Plot with title “UES RW score for applying jobs with LinkedIn vs Handshake”

# %%
ues_fa_2 <- read.csv("/home/ashish/HCI_LABstudies_Results/ues_fa_task2.csv", sep = ",", colClasses = c("factor", "numeric", "numeric"))
head(ues_fa_2)

boxplot(ues_fa_2$FA_L, ues_fa_2$FA_H, names=c("LinkedIn", "Handshake"), main="UES FA score for registering events with LinkedIn vs Handshake", ylab="UES FA score")
# Out:
#   PID FA_L     FA_H
# 1 1   5.000000 1.666667
# 2 4   2.000000 3.000000
# 3 5   3.333333 2.666667
# 4 2   3.333333 3.000000
# 5 3   3.666667 2.000000
# 6 6   3.000000 3.000000
# Plot with title “UES FA score for registering events with LinkedIn vs Handshake”

# %%
ues_pu_2 <- read.csv("/home/ashish/HCI_LABstudies_Results/ues_pu_task2.csv", sep = ",", colClasses = c("factor", "numeric", "numeric"))
head(ues_pu_2)

boxplot(ues_pu_2$PU_L, ues_pu_2$PU_H, names=c("LinkedIn", "Handshake"), main="UES PU score for registering events with LinkedIn vs Handshake", ylab="UES PU score")
# Out:
#   PID PU_L     PU_H
# 1 1   1.000000 5.000000
# 2 4   2.000000 3.000000
# 3 5   1.666667 4.000000
# 4 2   2.333333 1.333333
# 5 3   1.666667 3.333333
# 6 6   5.000000 5.000000
# Plot with title “UES PU score for registering events with LinkedIn vs Handshake”

# %%
ues_ae_2 <- read.csv("/home/ashish/HCI_LABstudies_Results/ues_ae_task2.csv", sep = ",", colClasses = c("factor", "numeric", "numeric"))
head(ues_ae_2)

boxplot(ues_ae_2$AE_L, ues_ae_2$AE_H, names=c("LinkedIn", "Handshake"), main="UES AE score for registering events with LinkedIn vs Handshake", ylab="UES AE score")
# Out:
#   PID AE_L     AE_H
# 1 1   3.000000 3.000000
# 2 4   2.000000 3.666667
# 3 5   2.000000 3.000000
# 4 2   2.666667 2.333333
# 5 3   1.000000 2.000000
# 6 6   3.000000 3.000000
# Plot with title “UES AE score for registering events with LinkedIn vs Handshake”

# %%
ues_rw_2 <- read.csv("/home/ashish/HCI_LABstudies_Results/ues_rw_task2.csv", sep = ",", colClasses = c("factor", "numeric", "numeric"))
head(ues_rw_2)

boxplot(ues_rw_2$RW_L, ues_rw_2$RW_H, names=c("LinkedIn", "Handshake"), main="UES RW score for registering events with LinkedIn vs Handshake", ylab="UES RW score")
# Out:
#   PID RW_L     RW_H
# 1 1   1.000000 3.666667
# 2 4   1.666667 2.333333
# 3 5   1.000000 2.000000
# 4 2   1.000000 1.000000
# 5 3   3.666667 4.666667
# 6 6   3.666667 3.000000
# Plot with title “UES RW score for registering events with LinkedIn vs Handshake”
